# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import japanize_matplotlib
import ydata_profiling as pdp
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from graphviz import Digraph

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot') #グラフのスタイル
plt.rcParams['figure.figsize'] = [12, 9] # グラフサイズ設定
plt.rcParams['font.size'] = 14 #フォントサイズ

# %%
#①AirREGIヘルプデスク日次入電数
data1 = pd.read_csv("regi_call_data_transform.csv", 
                    index_col='cdr_date',           
                    parse_dates=True)

#②AirREGIアカウント日次獲得数
data2 = pd.read_csv("regi_acc_get_data_transform.csv",
                    index_col='cdr_date',           
                    parse_dates=True)

#③AirPAYのCM実施フラグ
data3 = pd.read_csv("cm_data.csv", 
                    index_col='cdr_date',          
                    parse_dates=True)

#④GoogleTrendの関連ワード検索数（週次データ）
data4 = pd.read_csv("gt_service_name.csv", 
                    index_col='cdr_date', 
                    parse_dates=True)

#⑤カレンダーデータ
data5 = pd.read_csv("calender_data.csv", 
                    index_col='cdr_date',           
                    parse_dates=True)
                    
#⑥GoogleTrend "モバイル POS"検索数（週次データ）
data6 = pd.read_csv("google_trends.csv", 
                    index_col='cdr_date',          
                    parse_dates=True)

# %%
data1.head()
# Out:
#             call_num
# cdr_date
# 2018-06-01       183
# 2018-06-02         0
# 2018-06-03         0
# 2018-06-04       213
# 2018-06-05       143

# %%
data2.head()
# Out:
#             acc_get_cnt
# cdr_date
# 2018-05-01    -0.926645
# 2018-05-02    -0.567495
# 2018-05-03    -1.050489
# 2018-05-04    -1.199103
# 2018-05-05    -1.360101

# %%
data3.head()
# Out:
#             cm_flg
# cdr_date
# 2018-03-01       0
# 2018-03-02       0
# 2018-03-03       0
# 2018-03-04       0
# 2018-03-05       0

# %%
data4.head()
# Out:
#             search_cnt
# cdr_date
# 2018-03-04          49
# 2018-03-11          25
# 2018-03-18          31
# 2018-03-25          25
# 2018-04-01          19

# %%
data5.head()
# Out:
#             dow dow_name  woy  wom  doy  financial_year  \
# cdr_date
# 2018-06-01    5        金   22    1  152            2018
# 2018-06-02    6        土   22    1  153            2018
# 2018-06-03    7        日   22    2  154            2018
# 2018-06-04    1        月   23    2  155            2018
# 2018-06-05    2        火   23    2  156            2018
#
#             day_before_holiday_flag  holiday_flag holiday_name
# cdr_date
# 2018-06-01                     True         False          NaN
# 2018-06-02                     True          True          NaN
# 2018-06-03                    False          True          NaN
# 2018-06-04                    False         False          NaN
# 2018-06-05                    False         False          NaN

# %%
data6.head()
# Out:
#             search_trend
# cdr_date
# 2017-01-01            24
# 2017-02-01             0
# 2017-03-01            33
# 2017-04-01            30
# 2017-05-01             0

# %% [markdown]
# # データ結合＋特徴量作成

# %%
#acc_get_cntが標準化されているため
#StandardScalerを用いて"call_num"カラムを標準化し、データのスケールを合わせる
from sklearn.preprocessing import StandardScaler

df = pd.merge(data1, data2, on='cdr_date', how='inner')
scaler = StandardScaler()
df['call_num'] = scaler.fit_transform(df[['call_num']])
df.head()
# Out:
#             call_num  acc_get_cnt
# cdr_date
# 2018-06-01  0.555056    -0.282652
# 2018-06-02 -0.972049    -1.025720
# 2018-06-03 -0.972049    -1.075258
# 2018-06-04  0.805402    -0.220730
# 2018-06-05  0.221263    -0.431266

# %%
#差分系列をつくる
df = df.diff(1).dropna()
df.head()
# Out:
#             call_num  acc_get_cnt
# cdr_date
# 2018-06-02 -1.527106    -0.743068
# 2018-06-03  0.000000    -0.049538
# 2018-06-04  1.777451     0.854528
# 2018-06-05 -0.584139    -0.210536
# 2018-06-06 -0.100138     0.136229

# %%
#特徴量の詳細はpdf参照
#目的変数(acc_get_cnt)に関する時系列特徴量

lag1 = df["acc_get_cnt"].shift(1)
lag7 = df["acc_get_cnt"].shift(7)
window7 = lag1.rolling(window=7).mean()
expanding = lag1.expanding().mean()

df = pd.concat([ df,
                 lag1,
                 lag7,
                 window7,
                 expanding],
                 axis = 1)
df.columns = ['call_num', 'acc_get_cnt', 'acc_get_cnt_lag1', 'acc_get_cnt_lag7', 'acc_get_cnt_window7', 'acc_get_cnt_expanding']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 669 entries, 2018-06-02 to 2020-03-31
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   call_num               669 non-null    float64
#  1   acc_get_cnt            669 non-null    float64
#  2   acc_get_cnt_lag1       668 non-null    float64
#  3   acc_get_cnt_lag7       662 non-null    float64
#  4   acc_get_cnt_window7    662 non-null    float64
#  5   acc_get_cnt_expanding  668 non-null    float64
# dtypes: float64(6)
# memory usage: 36.6 KB

# %%
#CM実施累積回数データを追加
data3['cm_cumsum'] = data3['cm_flg'].cumsum()
data3.head()
# Out:
#             cm_flg  cm_cumsum
# cdr_date
# 2018-03-01       0          0
# 2018-03-02       0          0
# 2018-03-03       0          0
# 2018-03-04       0          0
# 2018-03-05       0          0

# %%
#週次データと日次データの結合
merged_data = pd.merge(data5, data6, on='cdr_date', how = 'left')
merged_data = pd.merge(merged_data, data4, on='cdr_date', how='left')
#週次データを日次データに組み合わせるため、直前の非欠損値で埋める
merged_data['search_trend'] = merged_data['search_trend'].fillna(method='ffill')
merged_data['search_cnt'] = merged_data['search_cnt'].fillna(method='ffill')

#日曜日フラグ
merged_data['isSunday'] = (merged_data['dow'] == 7).astype(int)
merged_data.head(30)
# Out:
#             dow dow_name  woy  wom  doy  financial_year  \
# cdr_date
# 2018-06-01    5        金   22    1  152            2018
# 2018-06-02    6        土   22    1  153            2018
# 2018-06-03    7        日   22    2  154            2018
# 2018-06-04    1        月   23    2  155            2018
# 2018-06-05    2        火   23    2  156            2018
# 2018-06-06    3        水   23    2  157            2018
# 2018-06-07    4        木   23    2  158            2018
# 2018-06-08    5        金   23    2  159            2018
# 2018-06-09    6        土   23    2  160            2018
# 2018-06-10    7        日   23    3  161            2018
# 2018-06-11    1        月   24    3  162            2018
# 2018-06-12    2        火   24    3  163            2018
# 2018-06-13    3        水   24    3  164            2018
# 2018-06-14    4        木   24    3  165            2018
# 2018-06-15    5        金   24    3  166            2018
# 2018-06-16    6        土   24    3  167            2018
# 2018-06-17    7        日   24    4  168            2018
# 2018-06-18    1        月   25    4  169            2018
# 2018-06-19    2        火   25    4  170            2018
# 2018-06-20    3        水   25    4  171            2018
# 2018-06-21    4        木   25    4  172            2018
# 2018-06-22    5        金   25    4  173            2018
# 2018-06-23    6        土   25    4  174            2018
# 2018-06-24    7        日   25    5  175            2018
# 2018-06-25    1        月   26    5  176            2018
# 2018-06-26    2        火   26    5  177            2018
# 2018-06-27    3        水   26    5  178            2018
# 2018-06-28    4        木   26    5  179            2018
# 2018-06-29    5        金   26    5  180            2018
# 2018-06-30    6        土   26    5  181            2018
#
#             day_before_holiday_flag  holiday_flag holiday_name  search_trend  \
# cdr_date
# 2018-06-01                     True         False          NaN          27.0
# 2018-06-02                     True          True          NaN          27.0
# 2018-06-03                    False          True          NaN          27.0
# 2018-06-04                    False         False          NaN          27.0
# 2018-06-05                    False         False          NaN          27.0
# 2018-06-06                    False         False          NaN          27.0
# 2018-06-07                    False         False          NaN          27.0
# 2018-06-08                     True         False          NaN          27.0
# 2018-06-09                     True          True          NaN          27.0
# 2018-06-10                    False          True          NaN          27.0
# 2018-06-11                    False         False          NaN          27.0
# 2018-06-12                    False         False          NaN          27.0
# 2018-06-13                    False         False          NaN          27.0
# 2018-06-14                    False         False          NaN          27.0
# 2018-06-15                     True         False          NaN          27.0
# 2018-06-16                     True          True          NaN          27.0
# 2018-06-17                    False          True          NaN          27.0
# 2018-06-18                    False         False          NaN          27.0
# 2018-06-19                    False         False          NaN          27.0
# 2018-06-20                    False         False          NaN          27.0
# 2018-06-21                    False         False          NaN          27.0
# 2018-06-22                     True         False          NaN          27.0
# 2018-06-23                     True          True          NaN          27.0
# 2018-06-24                    False          True          NaN          27.0
# 2018-06-25                    False         False          NaN          27.0
# 2018-06-26                    False         False          NaN          27.0
# 2018-06-27                    False         False          NaN          27.0
# 2018-06-28                    False         False          NaN          27.0
# 2018-06-29                     True         False          NaN          27.0
# 2018-06-30                     True          True          NaN          27.0
#
#             search_cnt  isSunday
# cdr_date
# 2018-06-01         NaN         0
# 2018-06-02         NaN         0
# 2018-06-03        18.0         1
# 2018-06-04        18.0         0
# 2018-06-05        18.0         0
# 2018-06-06        18.0         0
# 2018-06-07        18.0         0
# 2018-06-08        18.0         0
# 2018-06-09        18.0         0
# 2018-06-10         6.0         1
# 2018-06-11         6.0         0
# 2018-06-12         6.0         0
# 2018-06-13         6.0         0
# 2018-06-14         6.0         0
# 2018-06-15         6.0         0
# 2018-06-16         6.0         0
# 2018-06-17        12.0         1
# 2018-06-18        12.0         0
# 2018-06-19        12.0         0
# 2018-06-20        12.0         0
# 2018-06-21        12.0         0
# 2018-06-22        12.0         0
# 2018-06-23        12.0         0
# 2018-06-24        31.0         1
# 2018-06-25        31.0         0
# 2018-06-26        31.0         0
# 2018-06-27        31.0         0
# 2018-06-28        31.0         0
# 2018-06-29        31.0         0
# 2018-06-30        31.0         0

# %%
df.reset_index(inplace=True)
df['cdr_date'] = pd.to_datetime(df['cdr_date'])
merged_inner = pd.merge(df, data3, on='cdr_date', how='inner')
dataX = pd.merge(merged_inner, merged_data, on='cdr_date', how='inner')

# "dow_name"カラム、 "holiday_name"カラム、"financial_year"カラムを削除する
dataX.drop(['dow_name', 'holiday_name', 'financial_year'], axis=1, inplace=True)
dataX.sample(30)
# Out:
#       cdr_date  call_num  acc_get_cnt  acc_get_cnt_lag1  acc_get_cnt_lag7  \
# 10  2018-06-12 -0.567449    -0.185767          0.978373         -0.210536
# 225 2019-01-13  0.000000    -0.334381         -0.829760         -0.012384
# 181 2018-11-30  0.308759    -0.272458          0.037153         -0.470610
# 565 2019-12-19  0.066759     0.099076          0.173383          0.272458
# 159 2018-11-08  0.033379     0.321996         -0.408688         -0.247689
# 4   2018-06-06 -0.100138     0.136229         -0.210536               NaN
# 505 2019-10-20  0.000000    -0.656377         -0.544917         -0.346765
# 69  2018-08-10 -0.016690    -0.099076          0.074307         -0.049538
# 357 2019-05-25 -1.235036    -1.188909         -0.049538         -0.953604
# 609 2020-02-01 -1.043105    -0.668761         -0.321996         -0.507763
# 362 2019-05-30  0.066759     0.049538          0.594455          0.185767
# 60  2018-08-01  0.066759     0.049538          0.037153         -0.309612
# 608 2020-01-31 -0.258690    -0.321996          0.346765         -0.346765
# 216 2019-01-04  0.150207     0.668761          0.037153         -0.160998
# 659 2020-03-22  0.000000     0.074307         -0.359150         -0.359150
# 96  2018-09-06 -1.109864    -0.024769         -0.284843          0.024769
# 0   2018-06-02 -1.527106    -0.743068               NaN               NaN
# 457 2019-09-02  3.571591     1.820517         -0.210536          1.733826
# 436 2019-08-12  0.000000     0.000000         -0.297227          1.015527
# 353 2019-05-21 -0.066759     0.321996          0.804991          0.173383
# 522 2019-11-06 -0.726001     0.173383          0.594455         -0.718299
# 204 2018-12-23  0.000000    -0.061922         -0.284843         -0.272458
# 313 2019-04-11  0.250345    -0.557301          0.173383         -0.260074
# 307 2019-04-05 -0.016690     0.136229         -0.260074         -0.037153
# 380 2019-06-17  1.468692     1.139371         -0.482994          0.842144
# 23  2018-06-25  1.251726     0.693530         -0.074307          0.582070
# 38  2018-07-10  0.016690     0.086691          0.520148          0.123845
# 466 2019-09-11  0.242000     1.027911         -0.024769          0.198152
# 384 2019-06-21 -0.016690     0.049538          0.272458          0.321996
# 576 2019-12-30  0.425587    -0.111460          0.086691          0.532532
#
#      acc_get_cnt_window7  acc_get_cnt_expanding  cm_flg  cm_cumsum  dow  woy  \
# 10             -0.007077               0.001238       0          8    2   24
# 225             0.024769              -0.002092       0         22    7    2
# 181             0.040692               0.002258       0         22    5   48
# 565            -0.001769               0.000153       0        160    4   51
# 159            -0.127383              -0.000467       0         22    4   45
# 4                    NaN              -0.037153       0          8    3   23
# 505             0.037153               0.000687       0        160    7   42
# 69              0.014154              -0.002513       0          8    5   32
# 357            -0.014154               0.001908       1         80    6   21
# 609             0.024769               0.000407       0        160    6    5
# 362            -0.001769               0.001471       1         85    4   22
# 60              0.014154              -0.003096       0          8    3   31
# 608             0.021231               0.000937       0        160    5    5
# 216            -0.086691              -0.004759       0         22    5    1
# 659            -0.030077              -0.000413       1        198    7   12
# 96              0.015923              -0.001677       0          8    4   36
# 0                    NaN                    NaN       0          8    6   22
# 457             0.090230               0.002249       1        118    1   36
# 436            -0.019461              -0.000142       1         98    1   33
# 353             0.017692               0.001123       1         76    2   21
# 522            -0.114999               0.000783       0        160    3   45
# 204            -0.031846              -0.003946       0         22    7   51
# 313             0.001769               0.003640       0         71    4   15
# 307            -0.206998               0.002824       0         71    5   14
# 380            -0.037153              -0.001727       0         86    1   25
# 23              0.003538              -0.033923       0          8    1   26
# 38              0.014154              -0.011081       0          8    2   28
# 466            -0.017692               0.006724       1        127    3   37
# 384             0.129152               0.002870       0         86    5   25
# 576            -0.023000              -0.001441       0        160    1    1
#
#      wom  doy  day_before_holiday_flag  holiday_flag  search_trend  \
# 10     3  163                    False         False          27.0
# 225    3   13                     True          True          43.0
# 181    5  334                     True         False          24.0
# 565    3  353                    False         False          30.0
# 159    2  312                    False         False          24.0
# 4      2  157                    False         False          27.0
# 505    4  293                    False          True          39.0
# 69     2  222                     True         False           0.0
# 357    4  145                     True          True          31.0
# 609    1   32                     True          True          35.0
# 362    5  150                    False         False          31.0
# 60     1  213                    False         False           0.0
# 608    5   31                     True         False          19.0
# 216    1    4                     True         False          43.0
# 659    4   82                    False          True          23.0
# 96     2  249                    False         False          35.0
# 0      1  153                     True          True          27.0
# 457    1  245                    False         False          24.0
# 436    3  224                    False          True          17.0
# 353    4  141                    False         False          31.0
# 522    2  310                    False         False          46.0
# 204    5  357                     True          True         100.0
# 313    2  101                    False         False          46.0
# 307    1   95                     True         False          46.0
# 380    4  168                    False         False          32.0
# 23     5  176                    False         False          27.0
# 38     2  191                    False         False          29.0
# 466    2  254                    False         False          24.0
# 384    4  172                     True         False          32.0
# 576    5  364                    False         False          30.0
#
#      search_cnt  isSunday
# 10          6.0         0
# 225        18.0         1
# 181        44.0         0
# 565        65.0         0
# 159        25.0         0
# 4          18.0         0
# 505        34.0         1
# 69         41.0         0
# 357        23.0         0
# 609        37.0         0
# 362        40.0         0
# 60         47.0         0
# 608        37.0         0
# 216         6.0         0
# 659        25.0         1
# 96         35.0         0
# 0           NaN         0
# 457        56.0         0
# 436        38.0         0
# 353        23.0         0
# 522        46.0         0
# 204        13.0         1
# 313        35.0         0
# 307        23.0         0
# 380        83.0         0
# 23         31.0         0
# 38         24.0         0
# 466        50.0         0
# 384        83.0         0
# 576        16.0         0

# %%
dataX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cdr_date                 669 non-null    datetime64[ns]
#  1   call_num                 669 non-null    float64
#  2   acc_get_cnt              669 non-null    float64
#  3   acc_get_cnt_lag1         668 non-null    float64
#  4   acc_get_cnt_lag7         662 non-null    float64
#  5   acc_get_cnt_window7      662 non-null    float64
#  6   acc_get_cnt_expanding    668 non-null    float64
#  7   cm_flg                   669 non-null    int64
#  8   cm_cumsum                669 non-null    int64
#  9   dow                      669 non-null    int64
#  10  woy                      669 non-null    int64
#  11  wom                      669 non-null    int64
#  12  doy                      669 non-null    int64
#  13  day_before_holiday_flag  669 non-null    bool
#  14  holiday_flag             669 non-null    bool
#  15  search_trend             669 non-null    float64
#  16  search_cnt               668 non-null    float64
#  17  isSunday                 669 non-null    int32
# dtypes: bool(2), datetime64[ns](1), float64(8), int32(1), int64(6)
# memory usage: 82.4 KB

# %% [markdown]
# # 三角特徴量作成（季節性を捉えるための特徴量）

# %%
# 空のデータフレーム生成
exog = pd.DataFrame()
exog.index = dataX.index

# 三角関数特徴量（Fourier terms）の生成関数
def fourier_terms_gen(seasonal,terms_num):
    
    #seasonal:周期
    #terms_num:Fourier termの数（sinとcosのセット数）
    
    for num in range(terms_num):
        num = num + 1
        sin_colname = 'sin'+str(seasonal)+'_'+ str(num)
        cos_colname = 'cos'+str(seasonal)+'_'+ str(num)
        exog[sin_colname] = np.sin(num * 2 * np.pi * exog.index / seasonal)
        exog[cos_colname] = np.cos(num * 2 * np.pi * exog.index / seasonal)
        
# 三角関数特徴量の生成
## １週間周期
fourier_terms_gen(
    seasonal=7,
    terms_num=7)

print(exog) #確認
# Out:
#            sin7_1    cos7_1        sin7_2    cos7_2        sin7_3    cos7_3  \
# 0    0.000000e+00  1.000000  0.000000e+00  1.000000  0.000000e+00  1.000000
# 1    7.818315e-01  0.623490  9.749279e-01 -0.222521  4.338837e-01 -0.900969
# 2    9.749279e-01 -0.222521 -4.338837e-01 -0.900969 -7.818315e-01  0.623490
# 3    4.338837e-01 -0.900969 -7.818315e-01  0.623490  9.749279e-01 -0.222521
# 4   -4.338837e-01 -0.900969  7.818315e-01  0.623490 -9.749279e-01 -0.222521
# ..            ...       ...           ...       ...           ...       ...
# 664 -7.818315e-01  0.623490 -9.749279e-01 -0.222521 -4.338837e-01 -0.900969
# 665 -1.952007e-15  1.000000 -3.904014e-15  1.000000 -2.332297e-13  1.000000
# 666  7.818315e-01  0.623490  9.749279e-01 -0.222521  4.338837e-01 -0.900969
# 667  9.749279e-01 -0.222521 -4.338837e-01 -0.900969 -7.818315e-01  0.623490
# 668  4.338837e-01 -0.900969 -7.818315e-01  0.623490  9.749279e-01 -0.222521
#
#            sin7_4    cos7_4        sin7_5    cos7_5        sin7_6    cos7_6  \
# 0    0.000000e+00  1.000000  0.000000e+00  1.000000  0.000000e+00  1.000000
# 1   -4.338837e-01 -0.900969 -9.749279e-01 -0.222521 -7.818315e-01  0.623490
# 2    7.818315e-01  0.623490  4.338837e-01 -0.900969 -9.749279e-01 -0.222521
# 3   -9.749279e-01 -0.222521  7.818315e-01  0.623490 -4.338837e-01 -0.900969
# 4    9.749279e-01 -0.222521 -7.818315e-01  0.623490  4.338837e-01 -0.900969
# ..            ...       ...           ...       ...           ...       ...
# 664  4.338837e-01 -0.900969  9.749279e-01 -0.222521  7.818315e-01  0.623490
# 665 -7.808028e-15  1.000000 -9.760036e-15  1.000000 -4.664594e-13  1.000000
# 666 -4.338837e-01 -0.900969 -9.749279e-01 -0.222521 -7.818315e-01  0.623490
# 667  7.818315e-01  0.623490  4.338837e-01 -0.900969 -9.749279e-01 -0.222521
# 668 -9.749279e-01 -0.222521  7.818315e-01  0.623490 -4.338837e-01 -0.900969
#
#            sin7_7  cos7_7
# 0    0.000000e+00     1.0
# 1   -2.449294e-16     1.0
# 2   -4.898587e-16     1.0
# 3   -7.347881e-16     1.0
# 4   -9.797174e-16     1.0
# ..            ...     ...
# 664  2.352708e-13     1.0
# 665 -1.366405e-14     1.0
# 666 -2.625989e-13     1.0
# 667 -5.115338e-13     1.0
# 668  1.490260e-13     1.0
#
# [669 rows x 14 columns]

# %%
# データを結合
df_tbl = pd.concat([dataX,
                    exog],
                   axis=1)

# 欠測値削除
df_tbl = df_tbl.dropna()

df_tbl.head()
# Out:
#      cdr_date  call_num  acc_get_cnt  acc_get_cnt_lag1  acc_get_cnt_lag7  \
# 7  2018-06-09 -0.801105    -0.297227         -0.569686         -0.743068
# 8  2018-06-10  0.000000    -0.421072         -0.297227         -0.049538
# 9  2018-06-11  1.468692     0.978373         -0.421072          0.854528
# 10 2018-06-12 -0.567449    -0.185767          0.978373         -0.210536
# 11 2018-06-13  0.250345     0.359150         -0.185767          0.136229
#
#     acc_get_cnt_window7  acc_get_cnt_expanding  cm_flg  cm_cumsum  dow  ...  \
# 7             -0.035384              -0.035384       0          8    6  ...
# 8              0.028307              -0.068115       0          8    7  ...
# 9             -0.024769              -0.107332       0          8    1  ...
# 10            -0.007077               0.001238       0          8    2  ...
# 11            -0.003538              -0.015762       0          8    3  ...
#
#           sin7_3    cos7_3        sin7_4    cos7_4        sin7_5    cos7_5  \
# 7  -7.347881e-16  1.000000 -9.797174e-16  1.000000 -1.224647e-15  1.000000
# 8   4.338837e-01 -0.900969 -4.338837e-01 -0.900969 -9.749279e-01 -0.222521
# 9  -7.818315e-01  0.623490  7.818315e-01  0.623490  4.338837e-01 -0.900969
# 10  9.749279e-01 -0.222521 -9.749279e-01 -0.222521  7.818315e-01  0.623490
# 11 -9.749279e-01 -0.222521  9.749279e-01 -0.222521 -7.818315e-01  0.623490
#
#           sin7_6    cos7_6        sin7_7  cos7_7
# 7  -1.469576e-15  1.000000 -1.714506e-15     1.0
# 8  -7.818315e-01  0.623490 -1.959435e-15     1.0
# 9  -9.749279e-01 -0.222521 -2.204364e-15     1.0
# 10 -4.338837e-01 -0.900969 -2.449294e-15     1.0
# 11  4.338837e-01 -0.900969  4.411204e-15     1.0
#
# [5 rows x 32 columns]

# %%
#連番の特徴量
df_tbl['t'] = pd.RangeIndex(start=0, stop=len(df_tbl))
df_tbl.tail()
# Out:
#       cdr_date  call_num  acc_get_cnt  acc_get_cnt_lag1  acc_get_cnt_lag7  \
# 664 2020-03-27  0.108483     0.185767         -0.099076         -0.718299
# 665 2020-03-28 -1.059795    -0.755453          0.185767         -0.359150
# 666 2020-03-29  0.000000    -0.421072         -0.755453          0.074307
# 667 2020-03-30  1.118208     0.334381         -0.421072          0.817375
# 668 2020-03-31 -0.275380     0.953604          0.334381          0.173383
#
#      acc_get_cnt_window7  acc_get_cnt_expanding  cm_flg  cm_cumsum  dow  ...  \
# 664            -0.024769               0.000951       1        203    5  ...
# 665             0.104383               0.001229       1        204    6  ...
# 666             0.047769               0.000093       1        205    7  ...
# 667            -0.023000              -0.000538       1        206    1  ...
# 668            -0.091999              -0.000037       1        207    2  ...
#
#        cos7_3        sin7_4    cos7_4        sin7_5    cos7_5        sin7_6  \
# 664 -0.900969  4.338837e-01 -0.900969  9.749279e-01 -0.222521  7.818315e-01
# 665  1.000000 -7.808028e-15  1.000000 -9.760036e-15  1.000000 -4.664594e-13
# 666 -0.900969 -4.338837e-01 -0.900969 -9.749279e-01 -0.222521 -7.818315e-01
# 667  0.623490  7.818315e-01  0.623490  4.338837e-01 -0.900969 -9.749279e-01
# 668 -0.222521 -9.749279e-01 -0.222521  7.818315e-01  0.623490 -4.338837e-01
#
#        cos7_6        sin7_7  cos7_7    t
# 664  0.623490  2.352708e-13     1.0  657
# 665  1.000000 -1.366405e-14     1.0  658
# 666  0.623490 -2.625989e-13     1.0  659
# 667 -0.222521 -5.115338e-13     1.0  660
# 668 -0.900969  1.490260e-13     1.0  661
#
# [5 rows x 33 columns]

# %%
df_tbl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 662 entries, 7 to 668
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cdr_date                 662 non-null    datetime64[ns]
#  1   call_num                 662 non-null    float64
#  2   acc_get_cnt              662 non-null    float64
#  3   acc_get_cnt_lag1         662 non-null    float64
#  4   acc_get_cnt_lag7         662 non-null    float64
#  5   acc_get_cnt_window7      662 non-null    float64
#  6   acc_get_cnt_expanding    662 non-null    float64
#  7   cm_flg                   662 non-null    int64
#  8   cm_cumsum                662 non-null    int64
#  9   dow                      662 non-null    int64
#  10  woy                      662 non-null    int64
#  11  wom                      662 non-null    int64
#  12  doy                      662 non-null    int64
#  13  day_before_holiday_flag  662 non-null    bool
#  14  holiday_flag             662 non-null    bool
#  15  search_trend             662 non-null    float64
#  16  search_cnt               662 non-null    float64
#  17  isSunday                 662 non-null    int32
#  18  sin7_1                   662 non-null    float64
#  19  cos7_1                   662 non-null    float64
#  20  sin7_2                   662 non-null    float64
#  21  cos7_2                   662 non-null    float64
#  22  sin7_3                   662 non-null    float64
#  23  cos7_3                   662 non-null    float64
#  24  sin7_4                   662 non-null    float64
#  25  cos7_4                   662 non-null    float64
#  26  sin7_5                   662 non-null    float64
#  27  cos7_5                   662 non-null    float64
#  28  sin7_6                   662 non-null    float64
#  29  cos7_6                   662 non-null    float64
#  30  sin7_7                   662 non-null    float64
#  31  cos7_7                   662 non-null    float64
#  32  t                        662 non-null    int64
# dtypes: bool(2), datetime64[ns](1), float64(22), int32(1), int64(7)
# memory usage: 164.2 KB

# %% [markdown]
# # CSV出力

# %%
df_tbl.to_csv('dataset.csv', index=False)
